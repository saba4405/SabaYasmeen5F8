# %% [markdown]
# <a href="https://colab.research.google.com/github/saba4405/SabaYasmeen5F8/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = np.array([[1],[2],[3],[4],[5]])
y = np.array([1,2,2.5,4,5])

# %%
model = LinearRegression()
model.fit(x , y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.scatter(x, y, color='blue')
plt.plot(x, y_pred, color='red')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): -0.10000000000000009
# Coefficient (β1): [1.]

# %%
x = np.random.rand(100, 1)
y = 2 * x + np.random.randn(100, 1)

# %%
plt.scatter(x, y, color='brown')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.scatter(x, y, color='crimson')  # Actual data points
plt.plot(x, y_pred, color='pink')  # Regression line
plt.title("Linear Regression")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): [-0.23991406]
# Coefficient (β1): [[2.47750579]]

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/kgsb24/rishi-college/refs/heads/main/datasets/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df[['Pregnancies','Glucose']]
# Out:
#      Pregnancies  Glucose
# 0              6      148
# 1              1       85
# 2              8      183
# 3              1       89
# 4              0      137
# ..           ...      ...
# 763           10      101
# 764            2      122
# 765            5      121
# 766            1      126
# 767            1       93
#
# [768 rows x 2 columns]
